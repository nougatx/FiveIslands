# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium


map1 = gpd.read_file('diomede3/landuse.geojson')
map2 = gpd.read_file('diomede3/buildings.geojson')
map3 = gpd.read_file('diomede3/roads.geojson')

map1_center = map1.centroid[0]
map1_location = [map1_center.y, map1_center.x]

map = folium.Map(location=map1_location)

folium.GeoJson(map2.geometry, name = 'buildings').add_to(map)
folium.GeoJson(map3.geometry, name = 'roads', 
               opacity = 0.7,
               color='lightcoral').add_to(map)

folium.LayerControl().add_to(map)
display(map)
# Out:
# C:\Users\Naseeba Rehman\AppData\Local\Temp\ipykernel_42304\1892928619.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map1_center = map1.centroid[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c61a87197b5061c1ddeb8de0d9cf4aa6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c61a87197b5061c1ddeb8de0d9cf4aa6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c61a87197b5061c1ddeb8de0d9cf4aa6 = L.map(
#                 &quot;map_c61a87197b5061c1ddeb8de0d9cf4aa6&quot;,
#                 {
#                     center: [65.81381947016418, -169.034562389784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8be7735e8c1bc5d6305e5c924b781b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f8be7735e8c1bc5d6305e5c924b781b0.addTo(map_c61a87197b5061c1ddeb8de0d9cf4aa6);
#
#
#
#         function geo_json_cd1d429141eaa5416184a3c03d0f0903_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cd1d429141eaa5416184a3c03d0f0903 = L.geoJson(null, {
#                 onEachFeature: geo_json_cd1d429141eaa5416184a3c03d0f0903_onEachFeature,
#
#         });
#
#         function geo_json_cd1d429141eaa5416184a3c03d0f0903_add (data) {
#             geo_json_cd1d429141eaa5416184a3c03d0f0903
#                 .addData(data);
#         }
#             geo_json_cd1d429141eaa5416184a3c03d0f0903_add({&quot;bbox&quot;: [-169.066679, 65.752851, -168.9502708, 65.8158669], &quot;features&quot;: [{&quot;bbox&quot;: [-169.0557575, 65.7535755, -169.0555635, 65.7536556], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0556333, 65.7536556], [-169.0555635, 65.7536036], [-169.0556877, 65.7535755], [-169.0557575, 65.7536275], [-169.0556333, 65.7536556]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0308631, 65.8102478, -169.0306042, 65.810355], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0306042, 65.8103098], [-169.0307419, 65.8102478], [-169.0308631, 65.8102931], [-169.0307255, 65.810355], [-169.0306042, 65.8103098]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0355906, 65.8137455, -169.0354564, 65.813807], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0354585, 65.8137455], [-169.0355906, 65.8137463], [-169.0355885, 65.813807], [-169.0354564, 65.8138062], [-169.0354585, 65.8137455]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0345792, 65.8139264, -169.0344584, 65.8139808], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0345792, 65.813967], [-169.0345009, 65.8139808], [-169.0344584, 65.8139401], [-169.0345367, 65.8139264], [-169.0345444, 65.8139337], [-169.0345792, 65.813967]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0337531, 65.8139473, -169.0335843, 65.814039], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0337531, 65.8140235], [-169.0336578, 65.814039], [-169.0335843, 65.8139628], [-169.0336795, 65.8139473], [-169.0336887, 65.8139568], [-169.0337531, 65.8140235]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0344703, 65.814056, -169.0340832, 65.8141948], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.034384, 65.814056], [-169.0344703, 65.8141468], [-169.0341695, 65.8141948], [-169.0340832, 65.814104], [-169.0342166, 65.8140827], [-169.0342077, 65.8140735], [-169.0342502, 65.8140662], [-169.034255, 65.8140711], [-169.03426, 65.8140761], [-169.034384, 65.814056]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0341973, 65.8139076, -169.0338718, 65.8140047], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0341973, 65.8139644], [-169.0340808, 65.8139814], [-169.0339211, 65.8140047], [-169.0338718, 65.8139478], [-169.034148, 65.8139076], [-169.0341973, 65.8139644]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0352597, 65.8136273, -169.034945, 65.8137617], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0352597, 65.8137187], [-169.0350651, 65.8137617], [-169.0349703, 65.8136895], [-169.034945, 65.8136703], [-169.0350316, 65.8136512], [-169.0351395, 65.8136273], [-169.0352597, 65.8137187]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Fea

# %% [markdown]
# removing point data to remove markups

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium


map1 = gpd.read_file('diomede3/landuse.geojson')
map2 = gpd.read_file('diomede3/buildings.geojson')
map3 = gpd.read_file('diomede3/roads.geojson')

# Create new GeoDataFrames for map2 and map3
map2_g = gpd.GeoDataFrame()
map2_g['geometry'] = map2.geometry

map3_g = gpd.GeoDataFrame()
map3_g['geometry'] = map3.geometry

# Remove rows that contain point geometries in map2_g and map3_g
map2_g = map2_g[~map2_g.geometry.type.isin(['Point'])]
map3_g = map3_g[~map3_g.geometry.type.isin(['Point'])]

map1_center = map1.centroid[0]
map1_location = [map1_center.y, map1_center.x]

map = folium.Map(location=map1_location)

folium.GeoJson(map2_g.geometry, name = 'buildings').add_to(map)
folium.GeoJson(map3_g.geometry, name = 'roads', 
               opacity = 0.7,
               color='lightcoral').add_to(map)

folium.LayerControl().add_to(map)
display(map)
# Out:
# C:\Users\Naseeba Rehman\AppData\Local\Temp\ipykernel_42304\611265424.py:12: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   map2_g['geometry'] = map2.geometry
# C:\Users\Naseeba Rehman\AppData\Local\Temp\ipykernel_42304\611265424.py:15: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   map3_g['geometry'] = map3.geometry
# C:\Users\Naseeba Rehman\AppData\Local\Temp\ipykernel_42304\611265424.py:21: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map1_center = map1.centroid[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_666256acfc9ea1795c058a53a22b06b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_666256acfc9ea1795c058a53a22b06b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_666256acfc9ea1795c058a53a22b06b2 = L.map(
#                 &quot;map_666256acfc9ea1795c058a53a22b06b2&quot;,
#                 {
#                     center: [65.81381947016418, -169.034562389784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bd63f31b16461ba745311a9e4fdf38c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8bd63f31b16461ba745311a9e4fdf38c.addTo(map_666256acfc9ea1795c058a53a22b06b2);
#
#
#
#         function geo_json_a5f4b6580596fc5050ec157e5108282d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a5f4b6580596fc5050ec157e5108282d = L.geoJson(null, {
#                 onEachFeature: geo_json_a5f4b6580596fc5050ec157e5108282d_onEachFeature,
#
#         });
#
#         function geo_json_a5f4b6580596fc5050ec157e5108282d_add (data) {
#             geo_json_a5f4b6580596fc5050ec157e5108282d
#                 .addData(data);
#         }
#             geo_json_a5f4b6580596fc5050ec157e5108282d_add({&quot;bbox&quot;: [-169.066679, 65.752851, -168.9502708, 65.8158669], &quot;features&quot;: [{&quot;bbox&quot;: [-169.0557575, 65.7535755, -169.0555635, 65.7536556], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0556333, 65.7536556], [-169.0555635, 65.7536036], [-169.0556877, 65.7535755], [-169.0557575, 65.7536275], [-169.0556333, 65.7536556]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0308631, 65.8102478, -169.0306042, 65.810355], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0306042, 65.8103098], [-169.0307419, 65.8102478], [-169.0308631, 65.8102931], [-169.0307255, 65.810355], [-169.0306042, 65.8103098]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0355906, 65.8137455, -169.0354564, 65.813807], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0354585, 65.8137455], [-169.0355906, 65.8137463], [-169.0355885, 65.813807], [-169.0354564, 65.8138062], [-169.0354585, 65.8137455]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0345792, 65.8139264, -169.0344584, 65.8139808], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0345792, 65.813967], [-169.0345009, 65.8139808], [-169.0344584, 65.8139401], [-169.0345367, 65.8139264], [-169.0345444, 65.8139337], [-169.0345792, 65.813967]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0337531, 65.8139473, -169.0335843, 65.814039], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0337531, 65.8140235], [-169.0336578, 65.814039], [-169.0335843, 65.8139628], [-169.0336795, 65.8139473], [-169.0336887, 65.8139568], [-169.0337531, 65.8140235]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0344703, 65.814056, -169.0340832, 65.8141948], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.034384, 65.814056], [-169.0344703, 65.8141468], [-169.0341695, 65.8141948], [-169.0340832, 65.814104], [-169.0342166, 65.8140827], [-169.0342077, 65.8140735], [-169.0342502, 65.8140662], [-169.034255, 65.8140711], [-169.03426, 65.8140761], [-169.034384, 65.814056]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0341973, 65.8139076, -169.0338718, 65.8140047], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0341973, 65.8139644], [-169.0340808, 65.8139814], [-169.0339211, 65.8140047], [-169.0338718, 65.8139478], [-169.034148, 65.8139076], [-169.0341973, 65.8139644]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-169.0352597, 65.8136273, -169.034945, 65.8137617], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-169.0352597, 65.8137187], [-169.0350651, 65.8137617], [-169.0349703, 65.8136895], [-169.034945, 65.8136703], [-169.0350316, 65.8136512], [-169.0351395, 65.8136273], [-169.0352597, 65.8137187]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Fea

# %% [markdown]
# center the map

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium


map1 = gpd.read_file('diomede3/landuse.geojson')
map2 = gpd.read_file('diomede3/buildings.geojson')
map3 = gpd.read_file('diomede3/roads.geojson')

# Create new GeoDataFrames for map2 and map3
map2_g = gpd.GeoDataFrame()
map2_g['geometry'] = map2.geometry

map3_g = gpd.GeoDataFrame()
map3_g['geometry'] = map3.geometry

# Remove rows that contain point geometries in map2_g and map3_g
map2_g = map2_g[~map2_g.geometry.type.isin(['Point'])]
map3_g = map3_g[~map3_g.geometry.type.isin(['Point'])]

lat, lng = 65.78507906407131, -168.9783413436392
map1_location = [lat,lng]

map = folium.Map(location=map1_location, zoom_start = 11)

folium.GeoJson(map2_g.geometry, name = 'buildings').add_to(map)
folium.GeoJson(map3_g.geometry, name = 'roads', 
               opacity = 0.7,
               color='lightcoral').add_to(map)

folium.LayerControl().add_to(map)
display(map)
# Out:
# C:\Users\Naseeba Rehman\AppData\Local\Temp\ipykernel_42304\2959307180.py:12: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   map2_g['geometry'] = map2.geometry
# C:\Users\Naseeba Rehman\AppData\Local\Temp\ipykernel_42304\2959307180.py:15: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   map3_g['geometry'] = map3.geometry
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_