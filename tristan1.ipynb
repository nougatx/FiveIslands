# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

map1 = gpd.read_file('tristan1/map/landcover.geojson')
map2 = gpd.read_file('tristan1/map/amenity_polygons.geojson')
map3 = gpd.read_file('tristan1/map/forests.geojson')
# print(map1.head())
# print(map2.head())

ax = map1.plot(color = 'palegoldenrod') 
ctx.add_basemap(ax)
map2.plot(ax = ax, color = 'brown')
# map3.plot(ax=ax, color = 'cyan')
# map2.plot()
plt.show()
# Out:
# c:\Users\Naseeba Rehman\AppData\Local\Programs\Python\Python311\Lib\site-packages\contextily\tile.py:645: UserWarning: The inferred zoom level of 30 is not valid for the current tile provider (valid zooms: 0 - 19).
#   warnings.warn(msg)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# import contextily as ctx
import folium

map1 = gpd.read_file('tristan1/map/landcover.geojson')
map2 = gpd.read_file('tristan1/map/roads.geojson')
map3 = gpd.read_file('tristan1/map/forests.geojson')

# print(map1.head())
map1_center = map1.centroid[0]
# print(map1_center)
map1_location = [map1_center.y, map1_center.x]
# print(map1_location)

map1_map = folium.Map(location=map1_location)
display(map1_map)
# Out:
# C:\Users\Naseeba Rehman\AppData\Local\Temp\ipykernel_1672\1226199109.py:11: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map1_center = map1.centroid[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

map1 = gpd.read_file('tristan1/map/landcover.geojson')
map2 = gpd.read_file('tristan1/map/buildings.geojson')
map3 = gpd.read_file('tristan1/map/roads.geojson')

map1_center = map1.centroid[0]
map1_location = [map1_center.y, map1_center.x]
print(map1_location)
map = folium.Map(location=map1_location, zoom_start=12)

# folium.GeoJson(map1.geometry).add_to(map)
folium.GeoJson(map2.geometry, name = 'buildings').add_to(map)
folium.GeoJson(map3.geometry, name = 'roads', color='lightcoral').add_to(map)

folium.LayerControl().add_to(map)
display(map)
# ax = map1.plot(color = 'palegoldenrod') 
# map2.plot(ax = ax, color = 'brown')
# plt.show()
# Out:
# C:\Users\Naseeba Rehman\AppData\Local\Temp\ipykernel_32744\1400487330.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map1_center = map1.centroid[0]
# [-37.155694976748045, -12.319081216777283]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %% [markdown]
# getting a better center

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

map1 = gpd.read_file('tristan1/map/landcover.geojson')
map2 = gpd.read_file('tristan1/map/buildings.geojson')
map3 = gpd.read_file('tristan1/map/roads.geojson')

x, y= -37.10880642711254, -12.288562569323755
map1_location = [x, y]
map = folium.Map(location=map1_location, zoom_start=12)

# folium.GeoJson(map1.geometry).add_to(map)
folium.GeoJson(map2.geometry, name = 'buildings').add_to(map)
folium.GeoJson(map3.geometry, name = 'roads', color='lightcoral').add_to(map)

folium.LayerControl().add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
